# %% [markdown]
# # Анализ данных об аренде велосипедов в Чикаго
#
# ## Описание данных:
#
# - **trip_id** — id поездки;
# - **start_time** — Дата и время начала поездки
# - **end_time** — Дата и время конца поездки
# - **bikeid** — id велосипеда
# - **tripduration** — продолжительность поездки в минутах
# - **from_station_id** — id станции начала поездки
# - **from_station_name** — название пункта отправления
# - **to_station_id** — id пункта прибытия
# - **to_station_name** — название пункта прибытия
# - **usertype** — тип пользователя
# - **gender** — пол (если subscriber)
# - **birthyear** — год рождения (если subscriber)

# %%
# Импорт библиотек
import os
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Задания:
#
# #### 1. Поместите колонку start_time в качестве индексов. Предварительно проверьте тип переменной, и приведите её к правильному, если необходимо.

# %%
# Считаем данные, установим колонку start_time как индекс
bikes_Q1 = pd.read_csv(r'D:\data_analysis\works\bikes_data\bikes_q1.csv',
                       parse_dates=['start_time', 'end_time'], index_col='start_time')
bikes_Q1.head()
# Out:
#                       trip_id            end_time  bikeid tripduration  \
# start_time
# 2018-01-22 20:04:31  17617135 2018-01-22 20:11:53    1131        442.0
# 2018-03-16 19:47:59  17897619 2018-03-16 20:04:00    6146        961.0
# 2018-03-14 18:49:20  17881307 2018-03-14 18:54:38    3847        318.0
# 2018-03-14 18:33:48  17881130 2018-03-14 19:07:40    1483      2,032.0
# 2018-02-05 17:39:14  17686289 2018-02-05 17:46:13    6391        419.0
#
#                      from_station_id           from_station_name  \
# start_time
# 2018-01-22 20:04:31              471  Francisco Ave & Foster Ave
# 2018-03-16 19:47:59              296      Broadway & Belmont Ave
# 2018-03-14 18:49:20              260  Kedzie Ave & Milwaukee Ave
# 2018-03-14 18:33:48              199      Wabash Ave & Grand Ave
# 2018-02-05 17:39:14              596      Benson Ave & Church St
#
#                      to_station_id              to_station_name    usertype  \
# start_time
# 2018-01-22 20:04:31            468        Budlong Woods Library  Subscriber
# 2018-03-16 19:47:59            253  Winthrop Ave & Lawrence Ave  Subscriber
# 2018-03-14 18:49:20            503    Drake Ave & Fullerton Ave  Subscriber
# 2018-03-14 18:33:48            199       Wabash Ave & Grand Ave  Subscriber
# 2018-02-05 17:39:14            605      University Library (NU)  Subscriber
#
#                      gender  birthyear
# start_time
# 2018-01-22 20:04:31  Female     1949.0
# 2018-03-16 19:47:59    Male     1988.0
# 2018-03-14 18:49:20    Male     1987.0
# 2018-03-14 18:33:48    Male     1990.0
# 2018-02-05 17:39:14    Male     1992.0

# %%
# Посмотрим на размерность данных
bikes_Q1.shape
# Out:
# (174215, 11)

# %%
# Посмотрим на типы данных в датафрейме
bikes_Q1.dtypes
# Out:
# trip_id                       int64
# end_time             datetime64[ns]
# bikeid                        int64
# tripduration                 object
# from_station_id               int64
# from_station_name            object
# to_station_id                 int64
# to_station_name              object
# usertype                     object
# gender                       object
# birthyear                   float64
# dtype: object

# %% [markdown]
# #### 2. В данных имеется как дата аренды, так и её точное время начала и окончания с точностью до секунд. Примените метод pd.resample() и агрегируйте данные по дням. В качестве ответа укажите максимальное число аренд за день.

# %%
bikes_Q1.trip_id.resample(rule='1d').count().max()
# Out:
# 4196

# %% [markdown]
# #### 3. Посмотрим на распределение количества аренд для разных групп пользователей (usertype) — customers и subscribers в данных за апрель.  Сделайте ресемпл по дням для каждой группы и в качестве ответа укажите число аренд за 18 апреля, сделанных пользователями типа Subscriber.

# %%
# Загрузим и считаем данные за апрель
bikes_april = pd.read_csv(r'D:\data_analysis\works\bikes_data\bikes_april.csv',
                          parse_dates=['start_time', 'end_time'], index_col='start_time')
bikes_april.head()
# Out:
#                       trip_id            end_time  bikeid tripduration  \
# start_time
# 2018-04-01 00:10:23  18000531 2018-04-01 00:22:12    5065        709.0
# 2018-04-01 00:15:49  18000533 2018-04-01 00:19:47    4570        238.0
# 2018-04-01 00:17:00  18000534 2018-04-01 00:22:53    1323        353.0
# 2018-04-01 00:20:00  18000536 2018-04-01 00:26:22    2602        382.0
# 2018-04-01 00:23:19  18000538 2018-04-01 00:35:01    4213        702.0
#
#                      from_station_id                from_station_name  \
# start_time
# 2018-04-01 00:10:23              228          Damen Ave & Melrose Ave
# 2018-04-01 00:15:49              128          Damen Ave & Chicago Ave
# 2018-04-01 00:17:00              130          Damen Ave & Division St
# 2018-04-01 00:20:00              121  Blackstone Ave & Hyde Park Blvd
# 2018-04-01 00:23:19               31        Franklin St & Chicago Ave
#
#                      to_station_id              to_station_name    usertype  \
# start_time
# 2018-04-01 00:10:23            219      Damen Ave & Cortland St  Subscriber
# 2018-04-01 00:15:49            130      Damen Ave & Division St  Subscriber
# 2018-04-01 00:17:00             69       Damen Ave & Pierce Ave  Subscriber
# 2018-04-01 00:20:00            351  Cottage Grove Ave & 51st St  Subscriber
# 2018-04-01 00:23:19            180        Ritchie Ct & Banks St  Subscriber
#
#                      gender  birthyear
# start_time
# 2018-04-01 00:10:23    Male     1983.0
# 2018-04-01 00:15:49    Male     1978.0
# 2018-04-01 00:17:00    Male     1991.0
# 2018-04-01 00:20:00  Female     1992.0
# 2018-04-01 00:23:19    Male     1985.0

# %%
# Сделаем агрегацию данных и выведем количество пользователей за указанный день
bikes_per_days =bikes_april \
                    .groupby('usertype') \
                    .trip_id \
                    .resample(rule='1d') \
                    .count()

bikes_per_days.loc[('Subscriber', '2018-04-18')]
# Out:
# 2196

# %% [markdown]
# #### 4. Объедините сэмплы данных за нужные месяцы в один общий датасет bikes. Сделайте преобразование по дням для каждой группы пользователей (usertype), затем выберите дни, в которые число аренд, сделанных customers, было больше, чем у subscribers.

# %%
# Считаем все файлы и объединим их в итоговый датафрейм
tree = os.walk(r'D:\data_analysis\works\bikes_data')

bikes = pd.DataFrame()

for path, dirs, files in tree:
    for file in files:
        if 'sample' in file.split('_'):
            file_path = '\\'.join([path, file])
            df = pd.read_csv(file_path, parse_dates=['start_time', 'end_time'])
            bikes = pd.concat([bikes, df], ignore_index=True)

# %%
# Сделаем индексом колонку start_time и посмотрим на данные
bikes.set_index(bikes.start_time, inplace=True)
bikes.head()
# Out:
#                       trip_id          start_time            end_time  bikeid  \
# start_time
# 2018-04-01 00:17:00  18000534 2018-04-01 00:17:00 2018-04-01 00:22:53    1323
# 2018-04-01 00:20:00  18000536 2018-04-01 00:20:00 2018-04-01 00:26:22    2602
# 2018-04-01 00:23:19  18000538 2018-04-01 00:23:19 2018-04-01 00:35:01    4213
# 2018-04-01 00:24:46  18000540 2018-04-01 00:24:46 2018-04-01 00:44:23    6401
# 2018-04-01 00:26:04  18000541 2018-04-01 00:26:04 2018-04-01 00:31:05    6333
#
#                     tripduration  from_station_id  \
# start_time
# 2018-04-01 00:17:00        353.0              130
# 2018-04-01 00:20:00        382.0              121
# 2018-04-01 00:23:19        702.0               31
# 2018-04-01 00:24:46      1,177.0              596
# 2018-04-01 00:26:04        301.0              145
#
#                                        from_station_name  to_station_id  \
# start_time
# 2018-04-01 00:17:00              Damen Ave & Division St             69
# 2018-04-01 00:20:00      Blackstone Ave & Hyde Park Blvd            351
# 2018-04-01 00:23:19            Franklin St & Chicago Ave            180
# 2018-04-01 00:24:46               Benson Ave & Church St            517
# 2018-04-01 00:26:04  Mies van der Rohe Way & Chestnut St             24
#
#                                  to_station_name    usertype  gender  \
# start_time
# 2018-04-01 00:17:00       Damen Ave & Pierce Ave  Subscriber    Male
# 2018-04-01 00:20:00  Cottage Grove Ave & 51st St  Subscriber  Female
# 2018-04-01 00:23:19        Ritchie Ct & Banks St  Subscriber    Male
# 2018-04-01 00:24:46        Clark St & Jarvis Ave  Subscriber    Male
# 2018-04-01 00:26:04     Fairbanks Ct & Grand Ave  Subscriber    Male
#
#                      birthyear
# start_time
# 2018-04-01 00:17:00     1991.0
# 2018-04-01 00:20:00     1992.0
# 2018-04-01 00:23:19     1985.0
# 2018-04-01 00:24:46     1974.0
# 2018-04-01 00:26:04     1984.0

# %%
# Сделаем агрегацию данных по дням и посчитаем количество пользователей с разделением по типу
bikes_count = bikes \
                .groupby('usertype') \
                .trip_id \
                .resample(rule='1d') \
                .count()

# %%
# Отобразим только те дни, в которые пользователей с типом Customer было больше чем Subscriber
(bikes_count.Customer > bikes_count.Subscriber) \
    .to_frame(name='more_customers_than_subscribers') \
    .query('more_customers_than_subscribers == True')
# Out:
#             more_customers_than_subscribers
# start_time
# 2018-05-27                             True
# 2018-09-02                             True

# %% [markdown]
# #### 5. В переменную bikes_summer сохраните наблюдения с 1 июня по 31 августа. Затем запишите в top_destination наиболее популярный пункт назначения (его название). Агрегируйте данные по дням и определите, в какой день в полученный пункт (top_destination) было совершено меньше всего поездок. Дату сохраните в bad_day.

# %%
# Сохраним в переменную bikes_summer данные по летним месяцам и отобразим первые 5 строк
bikes_summer = bikes.loc['2018-06-01': '2018-08-31']
bikes_summer.head()
# Out:
#                       trip_id          start_time            end_time  bikeid  \
# start_time
# 2018-06-01 00:04:40  18709077 2018-06-01 00:04:40 2018-06-01 00:06:47    3155
# 2018-06-01 00:06:08  18709080 2018-06-01 00:06:08 2018-06-01 00:24:18    2807
# 2018-06-01 00:08:01  18709086 2018-06-01 00:08:01 2018-06-01 00:32:55    2737
# 2018-06-01 00:09:02  18709091 2018-06-01 00:09:02 2018-06-01 00:19:21    6089
# 2018-06-01 00:09:28  18709092 2018-06-01 00:09:28 2018-06-01 00:14:44    2352
#
#                     tripduration  from_station_id  \
# start_time
# 2018-06-01 00:04:40        127.0              128
# 2018-06-01 00:06:08      1,090.0              258
# 2018-06-01 00:08:01      1,494.0              337
# 2018-06-01 00:09:02        619.0              210
# 2018-06-01 00:09:28        316.0              240
#
#                                 from_station_name  to_station_id  \
# start_time
# 2018-06-01 00:04:40       Damen Ave & Chicago Ave            214
# 2018-06-01 00:06:08       Logan Blvd & Elston Ave             69
# 2018-06-01 00:08:01        Clark St & Chicago Ave            225
# 2018-06-01 00:09:02     Ashland Ave & Division St             56
# 2018-06-01 00:09:28  Sheridan Rd & Irving Park Rd            303
#
#                                to_station_name    usertype  gender  birthyear
# start_time
# 2018-06-01 00:04:40      Damen Ave & Grand Ave  Subscriber  Female     1978.0
# 2018-06-01 00:06:08     Damen Ave & Pierce Ave    Customer     NaN        NaN
# 2018-06-01 00:08:01   Halsted St & Dickens Ave    Customer    Male     1988.0
# 2018-06-01 00:09:02  Desplaines St & Kinzie St  Subscriber    Male     1987.0
# 2018-06-01 00:09:28    Broadway & Cornelia Ave  Subscriber    Male     1997.0

# %%
# Сделаем агрегацию данных по дням и месту прибытия
destinations = bikes_summer \
                .groupby('to_station_name') \
                .trip_id \
                .resample(rule='1d') \
                .count()

# %%
# Запишем в переменную самое популярное место прибытия
top_destination = bikes_summer.to_station_name.value_counts().idxmax()
top_destination
# Out:
# 'Streeter Dr & Grand Ave'

# %%
# Отберем день с наименьшим количеством поездок к самому посещаемому месту
bad_day = destinations['Streeter Dr & Grand Ave'].idxmin().strftime('%Y-%m-%d')
bad_day
# Out:
# '2018-06-21'

# %% [markdown]
# #### 6. Куда больше всего ездят на выходных? Туда же, куда и в будние дни, или в другие пункты назначения?

# %%
# Создадим в датафрейме bikes_summer дополнительную колонку с названием дня недели
bikes_summer['weekday'] = bikes_summer.index.day_name()

# Создадим список с будними днями
weekdays = ['Monday', 'Tuesday', 'Wednesday','Thursday', 'Friday']

# Создадим дополнительную колонку, которая будет содержать 'Yes' если день выходной и 'No' если будний
bikes_summer['is_holiday'] = np.where(bikes_summer['weekday'].isin(weekdays), 'No', 'Yes')
bikes_summer.head()
# Out:
#                       trip_id          start_time            end_time  bikeid  \
# start_time
# 2018-06-01 00:04:40  18709077 2018-06-01 00:04:40 2018-06-01 00:06:47    3155
# 2018-06-01 00:06:08  18709080 2018-06-01 00:06:08 2018-06-01 00:24:18    2807
# 2018-06-01 00:08:01  18709086 2018-06-01 00:08:01 2018-06-01 00:32:55    2737
# 2018-06-01 00:09:02  18709091 2018-06-01 00:09:02 2018-06-01 00:19:21    6089
# 2018-06-01 00:09:28  18709092 2018-06-01 00:09:28 2018-06-01 00:14:44    2352
#
#                     tripduration  from_station_id  \
# start_time
# 2018-06-01 00:04:40        127.0              128
# 2018-06-01 00:06:08      1,090.0              258
# 2018-06-01 00:08:01      1,494.0              337
# 2018-06-01 00:09:02        619.0              210
# 2018-06-01 00:09:28        316.0              240
#
#                                 from_station_name  to_station_id  \
# start_time
# 2018-06-01 00:04:40       Damen Ave & Chicago Ave            214
# 2018-06-01 00:06:08       Logan Blvd & Elston Ave             69
# 2018-06-01 00:08:01        Clark St & Chicago Ave            225
# 2018-06-01 00:09:02     Ashland Ave & Division St             56
# 2018-06-01 00:09:28  Sheridan Rd & Irving Park Rd            303
#
#                                to_station_name    usertype  gender  birthyear  \
# start_time
# 2018-06-01 00:04:40      Damen Ave & Grand Ave  Subscriber  Female     1978.0
# 2018-06-01 00:06:08     Damen Ave & Pierce Ave    Customer     NaN        NaN
# 2018-06-01 00:08:01   Halsted St & Dickens Ave    Customer    Male     1988.0
# 2018-06-01 00:09:02  Desplaines St & Kinzie St  Subscriber    Male     1987.0
# 2018-06-01 00:09:28    Broadway & Cornelia Ave  Subscriber    Male     1997.0
#
#                     weekday is_holiday
# start_time
# 2018-06-01 00:04:40  Friday         No
# 2018-06-01 00:06:08  Friday         No
# 2018-06-01 00:08:01  Friday         No
# 2018-06-01 00:09:02  Friday         No
# 2018-06-01 00:09:28  Friday         No

# %%
# Сгруппируем данные по переменной is_holiday и посчитаем количество посещений по станциям
# Отсортируем посещения по будням и отобразим первые 15 строк
bikes_summer \
        .groupby('is_holiday') \
        .to_station_name \
        .value_counts() \
        .to_frame() \
        .rename(columns={'to_station_name': 'visits'}) \
        .reset_index() \
        .pivot(index='to_station_name', columns='is_holiday', values='visits') \
        .fillna(0) \
        .sort_values('No', ascending=False).head(15) \
        .style.background_gradient(subset=['No','Yes'], cmap='jet')
# Out:
# <style  type="text/css" >
# #T_4cd0657a_5394_11ec_b81a_30c9ab3407carow0_col0,#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow0_col1{
#             background-color:  #800000;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow1_col0{
#             background-color:  #ffcc00;
#             color:  #000000;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow1_col1,#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow6_col1{
#             background-color:  #0000a8;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow2_col0{
#             background-color:  #40ffb7;
#             color:  #000000;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow2_col1{
#             background-color:  #000092;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow3_col0{
#             background-color:  #26ffd1;
#             color:  #000000;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow3_col1{
#             background-color:  #0000c4;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow4_col0{
#             background-color:  #00acff;
#             color:  #000000;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow4_col1{
#             background-color:  #80ff77;
#             color:  #000000;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow5_col0{
#             background-color:  #005cff;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow5_col1,#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow7_col0,#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow8_col0,#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow11_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow6_col0{
#             background-color:  #0050ff;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow7_col1,#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow10_col1{
#             background-color:  #00c4ff;
#             color:  #000000;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow8_col1{
#             background-color:  #60ff97;
#             color:  #000000;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow9_col0{
#             background-color:  #0000fa;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow9_col1{
#             background-color:  #00009f;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow10_col0{
#             background-color:  #0000f1;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow11_col0{
#             background-color:  #0000c8;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow12_col0{
#             background-color:  #0000bb;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow12_col1,#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow13_col0{
#             background-color:  #00008d;
#             color:  #f1f1f1;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow13_col1{
#             background-color:  #0cf4eb;
#             color:  #000000;
#         }#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow14_col0,#T_4cd0657a_5394_11ec_b81a_30c9ab3407carow14_col1{
#             background-color:  #000080;
#             color:  #f1f1f1;
#         }</style><table id="T_4cd0657a_5394_11ec_b81a_30c9ab3407ca" ><thead>    <tr>        <th class="index_name level0" >is_holiday</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >Yes</th>    </tr>    <tr>        <th class="index_name level0" >to_station_name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4cd0657a_5394_11ec_b81a_30c9ab3407calevel0_row0" class="row_heading level0 row0" >Streeter Dr & Grand Ave</th>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow0_col0" class="data row0 col0" >7614.000000</td>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow0_col1" class="data row0 col1" >6026.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4cd0657a_5394_11ec_b81a_30c9ab3407calevel0_row1" class="row_heading level0 row1" >Canal St & Adams St</th>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow1_col0" class="data row1 col0" >6142.000000</td>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow1_col1" class="data row1 col1" >328.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4cd0657a_5394_11ec_b81a_30c9ab3407calevel0_row2" class="row_heading level0 row2" >Clinton St & Washington Blvd</th>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow2_col0" class="data row2 col0" >4857.000000</td>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow2_col1" class="data row2 col1" >199.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4cd0657a_5394_11ec_b81a_30c9ab3407calevel0_row3" class="row_heading level0 row3" >Clinton St & Madison St</th>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow3_col0" class="data row3 col0" >4694.000000</td>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow3_col1" class="data row3 col1" >447.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4cd0657a_5394_11ec_b81a_30c9ab3407calevel0_row4" class="row_heading level0 row4" >Lake Shore Dr & North Blvd</th>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow4_col0" class="data row4 col0" >4213.000000</td>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow4_col1" class="data row4 col1" >3092.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4cd0657a_5394_11ec_b81a_30c9ab3407calevel0_row5" class="row_heading level0 row5" >Michigan Ave & Washington St</th>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow5_col0" class="data row5 col0" >3835.000000</td>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow5_col1" class="data row5 col1" >755.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4cd0657a_5394_11ec_b81a_30c9ab3407calevel0_row6" class="row_heading level0 row6" >Daley Center Plaza</th>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow6_col0" class="data row6 col0" >3771.000000</td>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow6_col1" class="data row6 col1" >323.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4cd0657a_5394_11ec_b81a_30c9ab3407calevel0_row7" class="row_heading level0 row7" >Millennium Park</th>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow7_col0" class="data row7 col0" >3405.000000</td>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow7_col1" class="data row7 col1" >1984.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4cd0657a_5394_11ec_b81a_30c9ab3407calevel0_row8" class="row_heading level0 row8" >Theater on the Lake</th>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow8_col0" class="data row8 col0" >3357.000000</td>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow8_col1" class="data row8 col1" >2858.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4cd0657a_5394_11ec_b81a_30c9ab3407calevel0_row9" class="row_heading level0 row9" >Franklin St & Monroe St</th>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow9_col0" class="data row9 col0" >3315.000000</td>
#                         <td id="T_4cd0657a_5394_11ec_b81a_30c9ab3407carow9_col1" class="data row9 col1" >265.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4cd0657a_5394_11ec_b81a_30c9ab3407calevel0_row10" class="row_heading level0
