# %%
from math import comb
from math import factorial

# %% [markdown]
# # Задания:
#
# ### Вопрос 1. Количество различных слов, получаемых перестановкой букв в слове "папарацци" равно?
#
#
# ### Решение:
#
# В слове "папарацци" 2 раза повторяются буквы "п, ц", 3 раза "a", по одному разу "р" и "и". То есть из набора букв "а,п,ц,р,и" мы составляем слова в которых указанные буквы встречаются нужное количество раз. Это в точности полиномиальный коэффициент $ P(3,2,2,1,1) = \frac{9!}{3!\cdot 2! \cdot 2! \cdot 1! \cdot 1!} $

# %%
P = int(factorial(9)/(6 * 2**2))
print('Количество различных слов получаемых перестановкой букв в слове "папарацци" - {0:,}'.format(P).replace(',', ' '))
# Out:
# Количество различных слов получаемых перестановкой букв в слове "папарацци" - 15 120

# %% [markdown]
# ### Вопрос 2. У продавца антиквариата имеется 12 разных монет. Четверо нумизматов (Андрей, Борис, Виктор и Геннадий) купили эти монеты: Андрей и Борис по 4 монеты, а Виктор и Геннадий − по 2 монеты. Сколькими способами они могли осуществить свои покупки?
#
#
# ### Решение:
#
# Данная задача аналогична предыдущей: можно занумеровать нумизматов или считать, что мы собираем "слово" из четырёх букв А, четырёх букв Б, двух В и двух Г, тогда: $ P(4,4,2,2) = \frac{12!}{4!\cdot 4! \cdot 2! \cdot 2!} $

# %%
P = int(factorial(12)/(factorial(4) * factorial(4) * 2 * 2))
print('Количество различных способов осуществить покупки - {0:,}'.format(P).replace(',', ' '))
# Out:
# Количество различных способов осуществить покупки - 207 900

# %% [markdown]
# ### Вопрос 3. У продавца антиквариата имеется 12 разных монет. Четверо нумизматов купили эти монеты: ***какие-то двое по 4 монеты, а оставшиеся двое − по 2 монеты***. Сколькими способами они могли осуществить свои покупки?
#
#
# ### Решение:
#
# Теперь мы дополнительно выбираем, кому достанется 4 монеты, а кому 2. Выбираем двух нумизматов, котором достанется по 4 монеты (это можно сделать $ C_4^2 $ способами). А затем, как в предыдущей задаче раздаём им монеты $ P(4,4,2,2) $ способами. Итого, получаем: $ C_4^2 \cdot P(4,4,2,2) $

# %%
C = comb(4, 2)
P = int(factorial(12)/(factorial(4) * factorial(4) * 2 * 2))
print('Количество различных способов осуществить покупки - {0:,}'.format(C * P).replace(',', ' '))
# Out:
# Количество различных способов осуществить покупки - 1 247 400

# %% [markdown]
# ### Вопрос 4. В чемпионате Европы по футболу участвуют 24 команды. Золотые медали получает команда победитель, серебряные − команда, проигравшая в финале, бронзовые − две команды, которые проиграли в полуфинале. Сколькими способами могут распределиться медали между командами?
#
#
# ### Решение:
#
#
# Из 24 команд надо выбрать 1 победителя, 1 финалиста, 2 полуфиналиста и 20 команд, не попавших в полуфинал. Количество способов − полиномиальный коэффициент $ P(20,1,1,2) = \frac{24!}{20! \cdot 1! \cdot 1! \cdot 2!}  = \frac{24 \cdot 23 \cdot 22 \cdot 21}{2!} $

# %%
P = int(factorial(24)/(factorial(20) * 2))
print('Количество различных способов распределить медали между командами - {0:,}'.format(P).replace(',', ' '))
# Out:
# Количество различных способов распределить медали между командами - 127 512
